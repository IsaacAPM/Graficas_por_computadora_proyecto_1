# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
phi = 10
x = lambda t: np.sin(t)*phi*t/np.pi
y = lambda t: np.cos(t)*phi*t/np.pi

# %%
t = np.linspace(0,100,1000)
X = x(t)
Y = y(t)
plt.plot(X,Y)

# %%
t = 10
print(f"({x(t)}, {y(t)})")
# Out:
# (-17.316729788877467, -26.70847629203848)
